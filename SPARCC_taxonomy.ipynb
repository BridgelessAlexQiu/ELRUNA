# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import defaultdict
import community
from networkx.algorithms.community import greedy_modularity_communities
from networkx.algorithms.community import label_propagation_communities
import collections

# %% [markdown]
# <center> <h1> Comparison between the pre-network and the post-network </h1></center>
#
# ## Networks generated by SparCC:
# 1. __pre:__ '../data/1125/Rectum_SparCC/rectum_pre_out_edges.txt'
# 2. __post:__ '../data/1125/Rectum_SparCC/rectum_post_out_edges.txt'
# 3. __all:__ '../data/1125/Rectum_SparCC/rectum_all_out_edges.txt'

# %% [markdown]
# <center><h2>Basic comparison</center></h2>
#
# ### Results:
#
# __Pre-Network__ <br>
# `Number of nodes: 665` <br>
# `Number of edges: 20358` <br>
# `Average degree:  61.2271` <br>
#
# __Post-Network__<br>
# `Number of nodes: 674` <br>
# `Number of edges: 12595` <br>
# `Average degree:  37.3739`<br>
#
# __Number of common OTUs between pre-network and post-network__: `632`

# %%
# transform txt to edgelist file
pre_txt = open('../data/1125/Rectum_SparCC/rectum_pre_out_edges.txt', 'r')
post_txt = open('../data/1125/Rectum_SparCC/rectum_post_out_edges.txt', 'r')

pre_edgelist = open('../data/1125/Rectum_SparCC/rectum_pre_out_edges.edgelist', 'w')
post_edgelist = open('../data/1125/Rectum_SparCC/rectum_post_out_edges.edgelist', 'w')

#----------------------------------Pre-----------------------------------------

# skip the header
next(pre_txt)

# Ok, here, in the original file, the OTUid of each OTU is in the format: "1002005", and the double quote is included
# This is not very good, therefore, I didn't write the double quote into the edgelist file
for line in pre_txt:
    pre_edgelist.write(line.split('\t')[0][1:-1] + ' ' + line.split('\t')[1][1:-1] + '\n')
    
pre_txt.close()
pre_edgelist.close()


#----------------------------------Post-----------------------------------------
# skip the header
next(post_txt)

for line in post_txt:
    post_edgelist.write(line.split('\t')[0][1:-1] + ' ' + line.split('\t')[1][1:-1] + '\n')
    
post_txt.close()
post_edgelist.close()

# %%
# Read the network
pre_fname = '../data/1125/Rectum_SparCC/rectum_pre_out_edges.edgelist'
post_fname = '../data/1125/Rectum_SparCC/rectum_post_out_edges.edgelist'

pre_network = nx.read_edgelist(pre_fname)
post_network = nx.read_edgelist(post_fname)

# Print network information
print("pre-network: ")
print(nx.info(pre_network))

print('-----------------------')

print('post-network: ')
print(nx.info(post_network))
# Out:
# pre-network:
# Name:
# Type: Graph
# Number of nodes: 665
# Number of edges: 20358
# Average degree:  61.2271
# -----------------------
# post-network:
# Name:
# Type: Graph
# Number of nodes: 674
# Number of edges: 12595
# Average degree:  37.3739

# %% [markdown]
# <center><h2>Clauset-Newman-Moore'a Algorithm (Modularity Optimization)</h2></center>

# %%
# format: [community : (v1, v2, ..., vn)]
pre_cluster = greedy_modularity_communities(pre_network)
print("Number of clusters in the pre-network:", len(pre_cluster)) # 4

post_cluster = greedy_modularity_communities(post_network)
print("Number of clusters in the post-network:", len(post_cluster)) # 6
# Out:
# Number of clusters in the pre-network: 4
# Number of clusters in the post-network: 6

# %%
for c, v in enumerate(pre_cluster):
    print(c, len(v), sep = ' : ')
    
print("---------------------")

for c, v in enumerate(post_cluster):
    print(c, len(v), sep = ' : ')
# Out:
# 0 : 271
# 1 : 269
# 2 : 108
# 3 : 17
# ---------------------
# 0 : 428
# 1 : 156
# 2 : 77
# 3 : 6
# 4 : 4
# 5 : 3

# %%
#pre_OTUID, post_OTUID, format: {vertex : OTUID}

pre_list = list()  
post_list = list()

subgroup_clauset = []

for c1, v1 in enumerate(pre_cluster):
    for v in v1:
        pre_list.append(v)
    for c2, v2 in enumerate(post_cluster):
        print("pre-network cluster # {} & post-network cluster # {}".format(c1, c2))
        for v in v2:
            post_list.append(v)
        common = list(set(pre_list).intersection(post_list))
        print("number of common OTU: {}".format(len(common)))
        print("-------------------------------------")
        
        if len(common) >= 8:
            subgroup_clauset.append(common)
        
        post_list = list()
    pre_list = list()
# Out:
# pre-network cluster # 0 & post-network cluster # 0
# number of common OTU: 192
# -------------------------------------
# pre-network cluster # 0 & post-network cluster # 1
# number of common OTU: 37
# -------------------------------------
# pre-network cluster # 0 & post-network cluster # 2
# number of common OTU: 30
# -------------------------------------
# pre-network cluster # 0 & post-network cluster # 3
# number of common OTU: 2
# -------------------------------------
# pre-network cluster # 0 & post-network cluster # 4
# number of common OTU: 3
# -------------------------------------
# pre-network cluster # 0 & post-network cluster # 5
# number of common OTU: 1
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 0
# number of common OTU: 121
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 1
# number of common OTU: 101
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 2
# number of common OTU: 28
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 3
# number of common OTU: 3
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 4
# number of common OTU: 0
# -------------------------------------
# pre-network cluster # 1 & post-network cluster # 5
# number of common OTU: 2
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 0
# number of common OTU: 74
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 1
# number of common OTU: 12
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 2
# number of common OTU: 10
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 3
# number of common OTU: 0
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 4
# number of common OTU: 1
# -------------------------------------
# pre-network cluster # 2 & post-network cluster # 5
# number of common OTU: 0
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 0
# number of common OTU: 12
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 1
# number of common OTU: 2
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 2
# number of common OTU: 1
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 3
# number of common OTU: 0
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 4
# number of common OTU: 0
# -------------------------------------
# pre-network cluster # 3 & post-network cluster # 5
# number of common OTU: 0
# -------------------------------------

# %%
# A total of 10 groups
print(len(subgroup_clauset))

for c in subgroup_clauset:
    print("Number of OTUs in this group: {}: ".format(len(c)))
    print(c)
    print("------------------")
# Out:
# 10
# Number of OTUs in this group: 192:
# ['809486', 'New.0.ReferenceOTU411', '349901', '585419', '1082059', '1104529', '589792', 'New.0.ReferenceOTU384', '191237', 'New.0.CleanUp.ReferenceOTU145599', '689950', '1082607', '593209', 'New.0.ReferenceOTU369', '836783', 'New.0.CleanUp.ReferenceOTU21074', '573035', '874750', '4307652', '996116', '1033018', '1009362', 'New.0.ReferenceOTU660', '581982', 'New.0.CleanUp.ReferenceOTU42791', '539735', '1080820', 'New.3.ReferenceOTU478', '1048194', '27938', '1011954', 'New.0.CleanUp.ReferenceOTU109358', 'New.0.CleanUp.ReferenceOTU157', '812496', '790545', 'New.0.ReferenceOTU709', 'New.3.ReferenceOTU59', '540269', '830290', 'New.0.CleanUp.ReferenceOTU32288', '362965', '559613', 'New.0.ReferenceOTU547', 'New.3.ReferenceOTU105', '579608', '276149', '176591', '1082539', '1084952', '1009894', 'New.0.ReferenceOTU329', '807369', '925494', '805151', '1074210', '543151', '589597', '558885', 'New.0.ReferenceOTU323', '540737', '4395263', '1047041', 'New.0.ReferenceOTU346', '503387', '209511', '4422519', '255161', '183182', '966091', '589376', '909420', '1084417', '179845', '564704', 'New.0.ReferenceOTU432', '716006', 'New.0.ReferenceOTU254', '543684', 'New.0.ReferenceOTU165', '566216', '4440085', '754823', '4342113', '1052264', '108049', '938948', '721526', '1042850', 'New.0.ReferenceOTU34', '465989', 'New.0.CleanUp.ReferenceOTU15172', '510422', '873887', '780788', '279193', '830688', '1084157', '239345', '1099914', '369064', '322927', 'New.0.ReferenceOTU292', '269774', '269907', '777272', '823476', '893979', 'New.0.ReferenceOTU769', '1074625', 'New.0.ReferenceOTU428', 'New.0.ReferenceOTU806', '446403', '133075', '787709', '539305', '433739', '822419', '1086889', '953050', '586458', 'New.0.ReferenceOTU58', '968954', 'New.0.ReferenceOTU158', '239951', '933546', '1081815', '1101488', '879040', '128390', '1060029', '4028105', 'New.0.ReferenceOTU100', '509913', '2855257', '688714', '1076969', '435928', '530833', '4318989', '156145', '883748', '544313', '687940', '97361', '829814', '814277', '553623', '785526', '590586', '889661', '363305', 'New.0.ReferenceOTU37', '403068', '1011088', '1099802', '441265', '1003206', '420127', '529216', '836573', 'New.0.ReferenceOTU695', '740871', '1565317', '1834768', '956811', '248648', '719367', '588659', '788268', '199416', '865469', '570385', '152229', '929901', '1016923', '876170', '918840', '829851', '789831', '548576', 'New.0.CleanUp.ReferenceOTU74266', '1088305', '580411', '450209', '1145070', '1108638', '1059729', '574655', '238940', 'New.0.ReferenceOTU803', '894928', 'New.0.CleanUp.ReferenceOTU107099']
# ------------------
# Number of OTUs in this group: 37:
# ['593376', '1068572', '156357', '1108960', 'New.0.ReferenceOTU445', '578911', '805854', 'New.0.CleanUp.ReferenceOTU9034', '987760', '172413', '558264', '604966', 'New.0.CleanUp.ReferenceOTU32266', '516611', '534507', '1069592', 'New.0.ReferenceOTU103', '536986', '906820', 'New.0.ReferenceOTU680', '563240', '591699', 'New.0.ReferenceOTU649', 'New.0.ReferenceOTU703', '810672', '542066', '580625', 'New.0.CleanUp.ReferenceOTU24853', '233981', '667570', '1106617', '703741', '528421', '1068470', '552026', '206826', '165827']
# ------------------
# Number of OTUs in this group: 30:
# ['648540', '839235', '666666', '835594', '810959', '4404401', '1111582', '510174', '588210', '1111496', '941278', '587444', '1133602', '153687', 'New.0.ReferenceOTU18', '903158', 'New.0.ReferenceOTU265', 'New.1.CleanUp.ReferenceOTU26526', '818181', '940737', '1011712', '288029', '541086', '914108', '537290', '271297', '360432', '849156', '1084906', 'New.0.ReferenceOTU161']
# ------------------
# Number of OTUs in this group: 121:
# ['New.0.ReferenceOTU169', '861376', '1107011', '706432', '995960', 'New.0.CleanUp.ReferenceOTU122879', 'New.0.ReferenceOTU311', '759916', '1101451', 'New.0.ReferenceOTU296', '592832', '581231', '956625', '965048', '568556', 'New.0.CleanUp.ReferenceOTU125682', 'New.0.CleanUp.ReferenceOTU109902', '1075891', 'New.0.CleanUp.ReferenceOTU143701', '1083194', 'New.0.ReferenceOTU437', 'New.0.ReferenceOTU800', '656307', '1097359', 'New.0.CleanUp.ReferenceOTU102343', '588161', 'New.0.CleanUp.ReferenceOTU119987', '588165', '836539', '998905', '963854', '654742', '113396', 'New.0.ReferenceOTU347', '505587', '804735', 'New.1.ReferenceOTU85', '439036', '1077373', '587532', 'New.3.ReferenceOTU106', '3507733', '990864', '532336', 'New.0.ReferenceOTU358', '820086', 'New.0.ReferenceOTU75', '969805', '963779', '41476', 'New.0.ReferenceOTU121', '377613', 'New.0.CleanUp.ReferenceOTU56051', 'New.0.ReferenceOTU111', '1005844', '4363473', 'New.0.CleanUp.ReferenceOTU44415', '1068902', '574102', '646549', '807522', 'New.0.CleanUp.ReferenceOTU15705', 'New.0.ReferenceOTU587', 'New.0.CleanUp.ReferenceOTU17616', 'New.0.CleanUp.ReferenceOTU132519', 'New.0.ReferenceOTU568', '922761', 'New.0.ReferenceOTU113', 'New.0.ReferenceOTU225', '1083508', 'New.0.ReferenceOTU252', '813945', 'New.0.CleanUp.ReferenceOTU135290', 'New.0.CleanUp.ReferenceOTU104032', 'New.0.CleanUp.ReferenceOTU34183', 'New.0.CleanUp.ReferenceOTU136896', 'New.1.ReferenceOTU258', 'New.0.ReferenceOTU773', 'New.0.CleanUp.ReferenceOTU46312', 'New.0.CleanUp.ReferenceOTU108577', 'New.1.CleanUp.ReferenceOTU18348', '547808', 'New.0.ReferenceOTU77', 'New.0.CleanUp.ReferenceOTU103413', 'New.1.ReferenceOTU136', 'New.0.ReferenceOTU511', 'New.0.CleanUp.ReferenceOTU27380', '580254', 'New.0.CleanUp.ReferenceOTU102012', 'New.0.CleanUp.ReferenceOTU42022', '988314', 'New.0.CleanUp.ReferenceOTU91364', 'New.1.ReferenceOTU279', 'New.0.ReferenceOTU293', '134265', '974121', 'New.0.CleanUp.ReferenceOTU41194', '1075821', 'New.1.ReferenceOTU144', 'New.0.CleanUp.ReferenceOTU38474', '1051517', '612706', 'New.0.CleanUp.ReferenceOTU54406', '1139618', 'New.0.ReferenceOTU245', '297672', '1084865', '217386', 'New.1.ReferenceOTU94', '552922', '902334', '566062', 'New.0.CleanUp.ReferenceOTU96823', 'New.0.ReferenceOTU162', '917156', 'New.0.ReferenceOTU90', '1017181', '821717', '3393186', '593724', '1110317']
# ------------------
# Number of OTUs in this group: 101:
# ['291844', 'New.0.ReferenceOTU325', '4385756', '1062748', 'New.0.CleanUp.ReferenceOTU139618', '1002005', '132837', '768553', '1049387', '545445', '563572', '310003', '351979', '984831', '739614', '828483', '813418', 'New.1.ReferenceOTU264', '288283', '519864', '544847', 'New.0.ReferenceOTU359', '544680', 'New.0.CleanUp.ReferenceOTU111477', 'New.0.CleanUp.ReferenceOTU116380', '697479', '176420', 'New.0.CleanUp.ReferenceOTU15269', '9510', 'New.0.CleanUp.ReferenceOTU19193', 'New.0.ReferenceOTU745', '792393', 'New.0.ReferenceOTU177', '1108275', '1111294', 'New.0.ReferenceOTU43', '367535', 'New.0.CleanUp.ReferenceOTU22635', '609982', 'New.0.CleanUp.ReferenceOTU50341', '160015', 'New.0.ReferenceOTU138', '4360168', '535375', 'New.0.CleanUp.ReferenceOTU43340', '1109744', 'New.1.ReferenceOTU183', '814282', '364926', '1866742', 'New.0.CleanUp.ReferenceOTU10145', '1108289', '248395', '529652', 'New.0.ReferenceOTU41', '583656', '533373', 'New.1.ReferenceOTU5', '1111944', 'New.1.ReferenceOTU260', 'New.0.CleanUp.ReferenceOTU104626', 'New.0.ReferenceOTU782', '1107027', 'New.0.CleanUp.ReferenceOTU1621', '308081', '992510', '711803', 'New.0.ReferenceOTU453', '1108726', '942852', '544841', 'New.0.CleanUp.ReferenceOTU138349', 'New.0.ReferenceOTU357', 'New.0.ReferenceOTU174', '544480', '547396', '1106324', '388951', 'New.0.ReferenceOTU678', '152483', 'New.0.ReferenceOTU791', '541506', 'New.1.ReferenceOTU4', 'New.0.ReferenceOTU727', '582379', '541299', '572889', '820978', 'New.0.CleanUp.ReferenceOTU131470', '262095', '1654477', 'New.0.CleanUp.ReferenceOTU121273', '540982', '359750', '538602', '571320', 'New.0.CleanUp.ReferenceOTU77349', 'New.0.CleanUp.ReferenceOTU125389', '674655', 'New.0.ReferenceOTU392', '679245']
# ------------------
# Number of OTUs in this group: 28:
# ['585648', '334459', 'New.0.ReferenceOTU463', 'New.0.CleanUp.ReferenceOTU9575', '806566', '979107', '350697', 'New.3.ReferenceOTU285', '1044436', '4476095', 'New.0.ReferenceOTU427', '359984', 'New.0.ReferenceOTU216', 'New.0.ReferenceOTU179', '589547', '337083', '589691', 'New.0.CleanUp.ReferenceOTU109702', '42256', 'New.0.CleanUp.ReferenceOTU22451', 'New.0.CleanUp.ReferenceOTU37336', 'New.0.CleanUp.ReferenceOTU142303', '308309', '1108308', 'New.0.CleanUp.ReferenceOTU88650', '34791', '550936', '712677']
# ------------------
# Number of OTUs in this group: 74:
# ['592628', '538237', 'New.0.ReferenceOTU324', '845561', 'New.0.CleanUp.ReferenceOTU100929', 'New.0.ReferenceOTU541', 'New.0.ReferenceOTU23', '1107833', '593489', 'New.0.CleanUp.ReferenceOTU5129', '591748', '539213', '589754', '833645', 'New.0.CleanUp.ReferenceOTU73319', '898309', '2752360', '1029165', '833317', 'New.0.CleanUp.ReferenceOTU121922', 'New.1.ReferenceOTU214', 'New.0.ReferenceOTU739', 'New.0.ReferenceOTU167', '584109', '582018', 'New.0.CleanUp.ReferenceOTU32484', '164190', '861807', 'New.0.CleanUp.ReferenceOTU20069', '593997', '553648', 'New.0.CleanUp.ReferenceOTU106318', '939892', '37948', 'New.0.ReferenceOTU570', '584500', '182418', '588455', 'New.0.ReferenceOTU509', 'New.0.ReferenceOTU153', '532419', 'New.0.ReferenceOTU410', '807443', 'New.0.ReferenceOTU827', '1107128', 'New.0.ReferenceOTU176', 'New.0.ReferenceOTU107', 'New.0.CleanUp.ReferenceOTU53881', '554339', 'New.0.CleanUp.ReferenceOTU134906', '586093', 'New.0.ReferenceOTU246', '4428164', '587912', '300811', '1078248', '570444', 'New.0.CleanUp.ReferenceOTU14180', '265873', 'New.0.ReferenceOTU168', '585493', '941487', 'New.0.ReferenceOTU349', 'New.0.CleanUp.ReferenceOTU20164', '225795', '1083037', '589040', '590218', '900973', 'New.0.CleanUp.ReferenceOTU143240', '361600', '113013', '1040713', '996487']
# ------------------
# Number of OTUs in this group: 12:
# ['692154', 'New.0.CleanUp.ReferenceOTU111110', 'New.0.ReferenceOTU31', 'New.0.CleanUp.ReferenceOTU16366', '997439', '559527', '860929', 'New.0.ReferenceOTU421', '760967', '1013670', 'New.0.ReferenceOTU584', 'New.0.CleanUp.ReferenceOTU136263']
# ------------------
# Number of OTUs in this group: 10:
# ['1020605', '579141', '562010', '1078207', '580743', '279204', '578837', 'New.0.CleanUp.ReferenceOTU21853', '827497', '1076316']
# ------------------
# Number of OTUs in this group: 12:
# ['New.0.CleanUp.ReferenceOTU116408', '580495', '777466', '932696', 'New.0.CleanUp.ReferenceOTU11696', '919487', '822354', '1047075', '1108208', '889025', '154960', 'New.0.CleanUp.ReferenceOTU126975']
# ------------------

# %%
# name of the file: shedd.IL.core.0.0001.prob.txt

prob_fo = open('shedd.IL.core.0.0001.prob.txt')

# skip the two header lines
next(prob_fo)
next(prob_fo)

'''
format: line.split('\t')[0] is the OTUid, line.split('\t')[-1] is the taxonomy information separated by '; ' (note that it is a
semicolon followed by a whitespace). Therefore
line.split('\t')[-1].split('; ') is the array of taxonomy information of a specific OUT
Example: ['k__Bacteria', ' p__Bacteroidetes', ' c__Flavobacteriia', ' o__Flavobacteriales', ' f__Flavobacteriaceae', ' g__Mesonia', ' s__\n']
Note that the last element of the array is \n, also, taxonomic information only contains: 
    class, order, family, genus
which are indices [2][3][4][5]
'''

# Here why I am doing this, for many OUTs, the taxonomy inforamtion are missing. For example, some don't have order information
# while others don't have genus info(acutally, a lot of them don't have genus information).
taxonomy_mapping = {'c': 'class', 'o' : 'order', 'f' : 'family', 'g' : 'genus'}
l = ['c', 'o', 'f', 'g']

# format: { OUTID : {class : c_xxx, order : o_xxx, family : f_xxx, genus : g_xxx} }
OTU_info = defaultdict(dict)

for line in prob_fo:
    for tax in line.split('\t')[-1].split('; '):
        if tax[0] in l:
            OTU_info[ line.split('\t')[0] ][taxonomy_mapping[tax[0]] ] = tax

# %%
print(OTU_info['113013'])
# Out:
# {'class': 'c__Flavobacteriia', 'order': 'o__Flavobacteriales', 'family': 'f__Flavobacteriaceae', 'genus': 'g__Mesonia'}
